# %% [markdown]
# ### @Collector and Speaker : little snow
# ### @Owner : 考研数学计算机之路 2024-2025 LLM微调实战项目

# %% [markdown]
# # 用GRU做一个分类器的重点解读:
# ### 输入一个新的名字，模型能基于这个名字的**拼写**给出他属于哪个语种地区。

# %% [markdown]
# ### 关于数据集

# %%
from IPython import display
display.Image(filename="picture/gru_dataset.png", width=400)

# %% [markdown]
# ### 左边是模型的输入，右边是模型输出，而输出共分为18种语言，也就是18种类别, 为了方便，把对应输出类别换成索引：

# %%
display.Image(filename="picture/Country2Index.png", width=400)

# %%
display.Image(filename="picture/GRU_模型总览.png", width=800)

# %% [markdown]
# #### 可以确定这是一个多分类问题，也意味着模型最后的输出将会是一个概率分布，包含18个概率，分别对应每一种语种地区！那Embedding的输入shape为多少呢？

# %% [markdown]
# ### 处理输入：字符串 -> 单个字符组成的列表 -> ASCII 列表

# %%
display.Image(filename="picture/String_Char_ASCII.png", width=800)

# %% [markdown]
# #### 所以我们输入的Shape应该是128，因为ASCII码一共包含了128个字符！
# #### 但是问题来了，某个Batch中包含的n个ASCII码列表长度不一致，**而维度数量不一致是没办法构造为张量的！**，那就Padding一下！

# %%
display.Image(filename="picture/Padding.png", width=800)

# %%
# [请复制到终端运行] 代码部分单独放在一起，在同级目录，直接运行训练
python p13_GRU_Classifier.py
# Out:
# ^C
# d:\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# d:\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# d:\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# Training for 25 epochs...
#  11s] Epoch 1 [2560/13374] loss=0.008931291149929165
#  20s] Epoch 1 [5120/13374] loss=0.007767519797198474
#  31s] Epoch 1 [7680/13374] loss=0.007009730379407605
#  41s] Epoch 1 [10240/13374] loss=0.006498963036574423
#  51s] Epoch 1 [12800/13374] loss=0.0061730548087507485
# evaluating trained model ...
# Test set: Accuracy 4470/6700 66.72%
#  13s] Epoch 2 [2560/13374] loss=0.004252688074484467
#  23s] Epoch 2 [5120/13374] loss=0.0041133123217150565
#  32s] Epoch 2 [7680/13374] loss=0.00408101570016394
#  41s] Epoch 2 [10240/13374] loss=0.0039676660322584215
# ...

# %% [markdown]
# ### GRU分类器的准确率随Epoch变化指标图

# %%
# 训练结束后才会生成指标结果图片，训练完成再执行，不然会报错
display.Image(filename="picture/rnn_classifier_accuracy_plot.png", width=800)
